# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
listings = pd.read_csv('Downloads/listings.csv')
# Out:
# /Users/lunatesuncar/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (61,62,94) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
listings.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   2818   https://www.airbnb.com/rooms/2818  20200608201310   2020-06-10
# 1   9693   https://www.airbnb.com/rooms/9693  20200608201310   2020-06-10
# 2  20168  https://www.airbnb.com/rooms/20168  20200608201310   2020-06-10
# 3  25428  https://www.airbnb.com/rooms/25428  20200608201310   2020-06-10
# 4  27886  https://www.airbnb.com/rooms/27886  20200608201310   2020-06-10
#
#                                                 name  \
# 0           Quiet Garden View Room & Super Fast WiFi
# 1                Top Location on Canal (Center Flat)
# 2       Studio with private bathroom in the centre 1
# 3    Lovely apt in City Centre (w.lift) near Jordaan
# 4  Romantic, stylish B&B houseboat in canal district
#
#                                              summary  \
# 0           Quiet Garden View Room & Super Fast WiFi
# 1  You will love your stay here. It is a beautifu...
# ...

# %%
neighborhoods = pd.read_csv ('Downloads/neighbourhoods.csv')

# %%
neighborhoods.head()
# Out:
#    neighbourhood_group           neighbourhood
# 0  City of Los Angeles         Adams-Normandie
# 1  City of Los Angeles                  Arleta
# 2  City of Los Angeles       Arlington Heights
# 3  City of Los Angeles         Atwater Village
# 4  City of Los Angeles  Baldwin Hills/Crenshaw

# %%
reviews = pd.read_csv ('Downloads/reviews.csv')

# %%
reviews.head()
# Out:
#    listing_id         id        date  reviewer_id reviewer_name  \
# 0         109     449036  2011-08-15       927861         Edwin
# 1         109   74506539  2016-05-15     22509885          Jenn
# 2         344   79805581  2016-06-14      2089550  Drew & Katie
# 3         344  120725697  2016-12-11     32602867   Christopher
# 4         344  123800867  2016-12-30     35822259           May
#
#                                             comments
# 0  The host canceled my reservation the day befor...
# 1  Me and two friends stayed for four and a half ...
# 2  We really enjoyed our stay here in Burbank! Th...
# 3  I had a ton of fun learning to play Go with Fu...
# 4  The host canceled this reservation the day bef...

# %%
pd.set_option('display.max_columns', None)
cols = listings.columns
pd.set_option('display.max_rows', 50)

# %%
listings.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   2818   https://www.airbnb.com/rooms/2818  20200608201310   2020-06-10
# 1   9693   https://www.airbnb.com/rooms/9693  20200608201310   2020-06-10
# 2  20168  https://www.airbnb.com/rooms/20168  20200608201310   2020-06-10
# 3  25428  https://www.airbnb.com/rooms/25428  20200608201310   2020-06-10
# 4  27886  https://www.airbnb.com/rooms/27886  20200608201310   2020-06-10
#
#                                                 name  \
# 0           Quiet Garden View Room & Super Fast WiFi
# 1                Top Location on Canal (Center Flat)
# 2       Studio with private bathroom in the centre 1
# 3    Lovely apt in City Centre (w.lift) near Jordaan
# 4  Romantic, stylish B&B houseboat in canal district
#
#                                              summary  \
# 0           Quiet Garden View Room & Super Fast WiFi
# 1  You will love your stay here. It is a beautifu...
# ...

# %%
LAlist = pd.read_csv ('Desktop/LAlist.csv')

# %%
LAlist.head()
# Out:
#      id                                               name  host_id  \
# 0   109  Amazing bright elegant condo park front *UPGRA...      521
# 1   344                  Family perfect;Pool;Near Studios!      767
# 2  2708           We Are Happy To Deeply Discount 30% Now.     3008
# 3  2732                              Zen Life at the Beach     3041
# 4  2864             * Beautiful Master Suite/Jacuzzi Tub/*     3207
#
#         host_name  neighbourhood_group neighbourhood  latitude  longitude  \
# 0           Paolo         Other Cities   Culver City  33.98209 -118.38494
# 1         Melissa         Other Cities       Burbank  34.16562 -118.33458
# 2           Chas.  City of Los Angeles     Hollywood  34.09768 -118.34602
# 3  Yoga Priestess         Other Cities  Santa Monica  34.00475 -118.48127
# 4       Bernadine         Other Cities    Bellflower  33.87619 -118.11397
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
LAlist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35757 entries, 0 to 35756
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              35757 non-null  int64
#  1   name                            35756 non-null  object
#  2   host_id                         35757 non-null  int64
#  3   host_name                       35653 non-null  object
#  4   neighbourhood_group             35757 non-null  object
#  5   neighbourhood                   35757 non-null  object
#  6   latitude                        35757 non-null  float64
#  7   longitude                       35757 non-null  float64
#  8   room_type                       35757 non-null  object
#  9   price                           35757 non-null  int64
#  10  minimum_nights                  35757 non-null  int64
#  11  number_of_reviews               35757 non-null  int64
# ...

# %%
mask = (LAlist.neighbourhood == 'Hollywood') | (LAlist.neighbourhood == 'Long Beach') | (LAlist.neighbourhood == 'Venice')

# %%
top3 = LAlist[mask]

# %%
top3.head()
# Out:
#       id                                              name  host_id host_name  \
# 2   2708          We Are Happy To Deeply Discount 30% Now.     3008     Chas.
# 9   6931  We've Happily Discounted 30% During This Period.     3008     Chas.
# 12  8770               Cozy Guest House on Venice Walk St.    26996   Lillian
# 13  9140                                  City Place Lofts    28350       NaN
# 15  9376                  Bright Apt, walk to Venice Beach    30319  Cristina
#
#     neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 2   City of Los Angeles     Hollywood  34.09768 -118.34602     Private room
# 9   City of Los Angeles     Hollywood  34.09521 -118.34801     Private room
# 12  City of Los Angeles        Venice  33.99399 -118.45637  Entire home/apt
# 13         Other Cities    Long Beach  33.77206 -118.18893     Private room
# 15  City of Los Angeles        Venice  33.99638 -118.47734     Private room
#
# ...

# %%
lalistings = pd.read_csv ('Downloads/lalistings.csv')
# Out:
# /Users/lunatesuncar/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (61,62) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
lalistings.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0   109   https://www.airbnb.com/rooms/109  20200610033538   2020-06-11
# 1   344   https://www.airbnb.com/rooms/344  20200610033538   2020-06-12
# 2  2708  https://www.airbnb.com/rooms/2708  20200610033538   2020-06-10
# 3  2732  https://www.airbnb.com/rooms/2732  20200610033538   2020-06-11
# 4  2864  https://www.airbnb.com/rooms/2864  20200610033538   2020-06-10
#
#                                                 name  \
# 0  Amazing bright elegant condo park front *UPGRA...
# 1                  Family perfect;Pool;Near Studios!
# 2           We Are Happy To Deeply Discount 30% Now.
# 3                              Zen Life at the Beach
# 4             * Beautiful Master Suite/Jacuzzi Tub/*
#
#                                              summary  \
# 0  *** Unit upgraded with new bamboo flooring, br...
# 1  This home is perfect for families; aspiring ch...
# ...

# %%
mask2 = (lalistings.neighbourhood == 'Hollywood') | (lalistings.neighbourhood == 'Long Beach') | (lalistings.neighbourhood == 'Venice')

# %%
la3 = lalistings[mask2]

# %%
la3.head()
# Out:
#       id                        listing_url       scrape_id last_scraped  \
# 2   2708  https://www.airbnb.com/rooms/2708  20200610033538   2020-06-10
# 9   6931  https://www.airbnb.com/rooms/6931  20200610033538   2020-06-11
# 12  8770  https://www.airbnb.com/rooms/8770  20200610033538   2020-06-10
# 13  9140  https://www.airbnb.com/rooms/9140  20200610033538   2020-06-10
# 14  9373  https://www.airbnb.com/rooms/9373  20200610033538   2020-06-12
#
#                                                 name  \
# 2           We Are Happy To Deeply Discount 30% Now.
# 9   We've Happily Discounted 30% During This Period.
# 12               Cozy Guest House on Venice Walk St.
# 13                                  City Place Lofts
# 14               CA Bungalow w/ garden; private room
#
#                                               summary  \
# 2   200 MBPS Highspeed Internet Highest Standard |...
# 9   200 MBPS Highspeed Internet Highest Standard |...
# ...

# %%
la3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6133 entries, 2 to 35755
# Columns: 106 entries, id to reviews_per_month
# dtypes: float64(21), int64(21), object(64)
# memory usage: 5.0+ MB

# %%
lalistings.describe()
# Out:
#                  id     scrape_id  thumbnail_url  medium_url  xl_picture_url  \
# count  3.575700e+04  3.575700e+04            0.0         0.0             0.0
# mean   2.524378e+07  2.020061e+13            NaN         NaN             NaN
# std    1.288914e+07  0.000000e+00            NaN         NaN             NaN
# min    1.090000e+02  2.020061e+13            NaN         NaN             NaN
# 25%    1.509982e+07  2.020061e+13            NaN         NaN             NaN
# 50%    2.627555e+07  2.020061e+13            NaN         NaN             NaN
# 75%    3.710344e+07  2.020061e+13            NaN         NaN             NaN
# max    4.372970e+07  2.020061e+13            NaN         NaN             NaN
#
#             host_id  host_listings_count  host_total_listings_count  \
# count  3.575700e+04         35653.000000               35653.000000
# mean   9.283381e+07            25.195664                  25.195664
# std    9.592864e+07           168.779782                 168.779782
# ...

# %%
lalistings['host_id'].value_counts().head(50)
# Out:
# 48005494     196
# 107434423    185
# 3843940       90
# 891818        81
# 174642927     67
# 31102550      64
# 147398503     64
# 4140161       62
# 101537031     62
# 25551648      57
# 89613524      56
# 328779387     56
# 112952162     55
# 154113511     54
# 4656446       50
# 183748799     47
# 159480876     46
# 25326961      42
# 120016074     41
# 134267499     41
# 134010948     41
# 3392276       41
# 9075429       40
# 23118355      38
# 23458477      37
# 67689189      37
# 230016718     35
# 10832832      35
# 168467528     33
# 30283594      32
# 137877395     31
# 12630342      30
# 21458609      30
# 5469474       30
# 4378151       30
# 91744093      29
# 301382231     28
# 20056779      28
# 1466173       27
# 4510013       27
# 57161         27
# 133276825     26
# 106941010     26
# 27447027      26
# 18530088      26
# 173872233     26
# 78557280      25
# 40225166      25
# 77561434      25
# 84963262      24
# Name: host_id, dtype: int64

# %%
hostplot = sns.countplot(x="host_id", data=lalistings)

# %%
#lalistings_grouped = lalistings.groupby('host_id', 'host_listings_count', 'host_is_superhost', 'neighbourhood', 'property_type', 'price'
                                        ,'cleaning_fee', 'minimum_nights')
lalistings.columns()
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        ...
#        'instant_bookable', 'is_business_travel_ready', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object', length=106)

# %%
lalistings_grouped.head()
# Out:
#              id                            listing_url       scrape_id  \
# 0           109       https://www.airbnb.com/rooms/109  20200610033538
# 1           344       https://www.airbnb.com/rooms/344  20200610033538
# 2          2708      https://www.airbnb.com/rooms/2708  20200610033538
# 3          2732      https://www.airbnb.com/rooms/2732  20200610033538
# 4          2864      https://www.airbnb.com/rooms/2864  20200610033538
# ...         ...                                    ...             ...
# 35750  43727452  https://www.airbnb.com/rooms/43727452  20200610033538
# 35751  43727590  https://www.airbnb.com/rooms/43727590  20200610033538
# 35754  43728212  https://www.airbnb.com/rooms/43728212  20200610033538
# 35755  43728503  https://www.airbnb.com/rooms/43728503  20200610033538
# 35756  43729698  https://www.airbnb.com/rooms/43729698  20200610033538
#
#       last_scraped                                               name  \
# ...

# %%
lalistings_less = lalistings.drop(lalistings.columns.difference(['id','host_id', 'calculated_host_listings_count', 'host_is_superhost', 'neighbourhood', 'property_type', 'price'
                                        ,'cleaning_fee', 'minimum_nights']), 1)

# %%
lalistings_less.tail()
# Out:
#              id    host_id host_is_superhost    neighbourhood property_type  \
# 35752  43727871  304488360                 f  Manhattan Beach         House
# 35753  43728042    7858796                 f           Malibu         House
# 35754  43728212  134267499                 t        Hollywood     Apartment
# 35755  43728503   98269878                 f           Venice         House
# 35756  43729698   19681805                 f        Inglewood         House
#
#            price cleaning_fee  minimum_nights  calculated_host_listings_count
# 35752    $496.00          NaN              30                               1
# 35753  $2,500.00          NaN               6                               6
# 35754     $72.00      $150.00              30                              41
# 35755    $200.00       $45.00              30                               1
# 35756     $85.00       $60.00               1                               3

# %%
lalistings_right = lalistings_less.sort_values('calculated_host_listings_count')

# %%
lalistings_right.tail(50)
# Out:
#              id   host_id host_is_superhost     neighbourhood  \
# 20817  30038974  48005494                 t      Santa Monica
# 25168  35236949  48005494                 t         Hollywood
# 30362  40203658  48005494                 t          Pasadena
# 28426  38726064  48005494                 t  West Los Angeles
# 28425  38725953  48005494                 t  West Los Angeles
# 17634  25979027  48005494                 t      Santa Monica
# 20782  29993436  48005494                 t      Santa Monica
# 25201  35277702  48005494                 t           Del Rey
# 34283  42927600  48005494                 t      Mid-Wilshire
# 17369  25545883  48005494                 t      Santa Monica
# 30365  40204209  48005494                 t          Pasadena
# 24400  34345903  48005494                 t          Downtown
# 24399  34345792  48005494                 t          Downtown
# 21976  31448002  48005494                 t          Mid-City
# ...

# %%
sns.pairplot(lalistings_right)

# %%
lalistings_right.to_csv('Downloads/lalistings_right.csv')

# %%
lalistings_right.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35757 entries, 0 to 33801
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              35757 non-null  int64
#  1   host_id                         35757 non-null  int64
#  2   host_is_superhost               35653 non-null  object
#  3   neighbourhood                   33749 non-null  object
#  4   property_type                   35757 non-null  object
#  5   price                           35757 non-null  object
#  6   cleaning_fee                    30910 non-null  object
#  7   minimum_nights                  35757 non-null  int64
#  8   calculated_host_listings_count  35757 non-null  int64
# dtypes: int64(4), object(5)
# memory usage: 4.0+ MB

# %%
lalistings_right['host_id'].value_counts()
# Out:
# 48005494     196
# 107434423    185
# 3843940       90
# 891818        81
# 174642927     67
#             ...
# 44840405       1
# 23078359       1
# 26385888       1
# 35884514       1
# 8982530        1
# Name: host_id, Length: 21234, dtype: int64

# %%
lalistings_right.max()
# Out:
# id                                 43729698
# host_id                           349213090
# property_type                          Yurt
# price                               $999.00
# minimum_nights                         1125
# calculated_host_listings_count          196
# dtype: object

# %%
host196 = lalistings_right['host_id'] == 48005494

# %%
lahost196 = lalistings_right[host196]

# %%
host196.value_counts()
# Out:
# False    35561
# True       196
# Name: host_id, dtype: int64

# %%
lahost196.head(10)
# Out:
#              id   host_id host_is_superhost neighbourhood       property_type  \
# 33815  42663939  48005494                 t      Glendale  Serviced apartment
# 30449  40263690  48005494                 t      Pasadena  Serviced apartment
# 30448  40263673  48005494                 t      Glendale  Serviced apartment
# 24616  34602723  48005494                 t     Hawthorne  Serviced apartment
# 18669  27433540  48005494                 t  Santa Monica  Serviced apartment
# 33281  42357322  48005494                 t      Glendale  Serviced apartment
# 33812  42663728  48005494                 t      Glendale  Serviced apartment
# 24264  34204508  48005494                 t      Downtown  Serviced apartment
# 18671  27433668  48005494                 t  Santa Monica  Serviced apartment
# 18672  27434106  48005494                 t  Santa Monica  Serviced apartment
#
#          price cleaning_fee  minimum_nights  calculated_host_listings_count
# ...

# %%
lahost196.to_csv('Downloads/lahost196.csv')

# %%
host185 = lalistings_right['host_id'] == 107434423

# %%
lahost185 = lalistings_right[host185]

# %%
lahost185.to_csv('Downloads/lahost185.csv')

# %%
host90 = lalistings_right['host_id'] == 3843940

# %%
lahost90 = lalistings_right[host90]

# %%
lahost90.to_csv('Downloads/lahost90.csv')

# %%
host81 = lalistings_right['host_id'] == 891818

# %%
lahost81 = lalistings_right[host81]

# %%
lahost81.to_csv('Downloads/lahost81.csv')
